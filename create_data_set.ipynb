# %%
import numpy as np
import matplotlib as mpl
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import os
import pickle
from tqdm.auto import tqdm
from scipy.ndimage import gaussian_filter
from utils_load_data import *
from utils_load_data import *

# 数据源（网络路径，用于从 Google Sheets 加载 sessions）
root_directory_remote = r'\\129.199.81.18\data5\eTheremin'

# 保存路径（本地 Desktop）
root_directory_base = r'C:\Users\PenPen\Desktop\Ferret\Data\\'
os.makedirs(root_directory_base, exist_ok=True)

mpl.rcdefaults()

### Parameters ###

dt = 0.005

headstage_of_interest = 0
spike_sorted = True
remove_baseline = False
session_type = 'mapping_change_only'

# %%
all_sheets = [
    # {"NAPOLEON": "1sFatSTXO0j3OONKstz7YN-mM04kNMjk_r7zo951yicU"},
    {"SKIEUR": "1sFatSTXO0j3OONKstz7YN-mM04kNMjk_r7zo951yicU"}
    #{"MMELOIK": "1sFatSTXO0j3OONKstz7YN-mM04kNMjk_r7zo951yicU"}, 
   #{"FETA": "1sFatSTXO0j3OONKstz7YN-mM04kNMjk_r7zo951yicU"}, 
    #{"HERCULE" : "1sFatSTXO0j3OONKstz7YN-mM04kNMjk_r7zo951yicU"}, 
    # {"MMELOIK" : "1sFatSTXO0j3OONKstz7YN-mM04kNMjk_r7zo951yicU"}
    ]

create_data_set(all_sheets, headstage_of_interest, session_type, dt, root_directory_base, spike_sorted, remove_baseline, gc_or_not=False)
# Out:
# SKIEUR
# 100%|██████████| 34/34 [00:00<00:00, 39701.10it/s]
# /auto/data6/eTheremin/SKIEUR/SKIEUR_20260331_SESSION_01/headstage_0/
# Error for file /auto/data6/eTheremin/SKIEUR/SKIEUR_20260331_SESSION_01/headstage_0/: [Errno 2] No such file or directory: '/auto/data6/eTheremin/SKIEUR/SKIEUR_20260331_SESSION_01/headstage_0/spike_sorting/data_0.05.npy'
# /auto/data6/eTheremin/SKIEUR/SKIEUR_20260331_SESSION_03/headstage_0/
# Error for file /auto/data6/eTheremin/SKIEUR/SKIEUR_20260331_SESSION_03/headstage_0/: [Errno 2] No such file or directory: '/auto/data6/eTheremin/SKIEUR/SKIEUR_20260331_SESSION_03/headstage_0/spike_sorting/data_0.05.npy'
# /auto/data6/eTheremin/SKIEUR/SKIEUR_20260401_SESSION_00/headstage_0/
# Error for file /auto/data6/eTheremin/SKIEUR/SKIEUR_20260401_SESSION_00/headstage_0/: [Errno 2] No such file or directory: '/auto/data6/eTheremin/SKIEUR/SKIEUR_20260401_SESSION_00/headstage_0/spike_sorting/data_0.05.npy'
# ...
